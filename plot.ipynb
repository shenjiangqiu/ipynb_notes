# %%
import matplotlib.pyplot as plt
import numpy as np
import os

data=np.loadtxt("ASG_96_len112_known_last12_2.txt")
plt.clf()

plt.plot(data[:,0].reshape(-1),data[:,1].reshape(-1))
plt.show()
print(data.shape)
print("average:%f" % np.average(data[:,1]))
plt.clf()
plt.plot(data[[i for i in range(0,1000000,10000)],0].reshape(-1),data[[i for i in range(0,1000000,10000)],1].reshape(-1))
plt.show()
# Out:
# (1000000, 2)
# average:32.375526

# %%
data=np.loadtxt("toughsat_30bits_0.cnf.txt")
plt.clf()
plt.plot(data[:,0].reshape(-1),data[:,1].reshape(-1))
plt.show()
plt.clf()
plt.plot(data[[i for i in range(0,1000000,10000)],0].reshape(-1),data[[i for i in range(0,1000000,10000)],1].reshape(-1))
plt.show()
print(data.shape)
print("average:%f" % np.average(data[:,1]))
# Out:
# (1000000, 2)
# average:21.580715
